# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
# !install pyarrow
# Out:
# install: missing destination file operand after 'pyarrow'
# Try 'install --help' for more information.

# %%
# !pip install pyarrow

# %%
df.head
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.head
#
# NameError: name 'df' is not defined

# %%
df = pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/misc/taxi_zones.zip')
# Out:
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df = pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/misc/taxi_zones.zip')
#
# File ~/anaconda3/lib/python3.13/site-packages/pandas/io/parquet.py:669, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     666     use_nullable_dtypes = False
#     667 check_dtype_backend(dtype_backend)
# --> 669 return impl.read(
#     670     path,
#     671     columns=columns,
#     672     filters=filters,
#     673     storage_options=storage_options,
#     674     use_nullable_dtypes=use_nullable_dtypes,
#     675     dtype_backend=dtype_backend,
#     676     filesystem=filesystem,
#     677     **kwargs,
#     678 )
#
# ...

# %%
df.head
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.head
#
# NameError: name 'df' is not defined

# %%
df = pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-01.parquet')

# %%
df.head
# Out:
# <bound method NDFrame.head of          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2025-01-01 00:18:38   2025-01-01 00:26:59              1.0
# 1               1  2025-01-01 00:32:40   2025-01-01 00:35:13              1.0
# 2               1  2025-01-01 00:44:04   2025-01-01 00:46:01              1.0
# 3               2  2025-01-01 00:14:27   2025-01-01 00:20:01              3.0
# 4               2  2025-01-01 00:21:34   2025-01-01 00:25:06              3.0
# ...           ...                  ...                   ...              ...
# 3475221         2  2025-01-31 23:01:48   2025-01-31 23:16:29              NaN
# 3475222         2  2025-01-31 23:50:29   2025-02-01 00:17:27              NaN
# 3475223         2  2025-01-31 23:26:59   2025-01-31 23:43:01              NaN
# 3475224         2  2025-01-31 23:14:34   2025-01-31 23:34:52              NaN
# 3475225         2  2025-01-31 23:56:42   2025-02-01 00:07:27              NaN
#
# ...

# %%
import sklearn

# %%
sklear.__version__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 sklear.__version__
#
# NameError: name 'sklear' is not defined

# %%
sklearn.__version__
# Out:
# '1.7.2'
